# %% [markdown]
# # Exercises

# %% [markdown]
# ### #1 - Find the Average Age of Runners in the Boston Marathon using a Pandas DataFrame

# %%
import csv
import numpy as np
import pandas as pd
bost = pd.read_csv('../files/boston_marathon2017_edited.csv')
bost_avg_age = bost['Age'].describe()['mean']
print(f'The average age of runners from the boston marathon is: {int(bost_avg_age)}')
# Out:
# The average age of runners from the boston marathon is: 42

# %% [markdown]
# ### #2 - Create a UDF <b>
# <p>Using the Boston Red Sox data, create your own UDF which creates a new column called 'All-Star' and puts every player with either a batting average over .280 or an on base percentage of over .360 with a result of 'Yes' in the column and 'No' if not.</p>

# %%
sox18 = pd.read_csv('../files/redsox_2018_hitting.txt')

def star(row):
    BA = row['BA']
    OBP = row['OBP']
    if BA >= .280 or OBP >= .360:
        return 'Yes'
    else:
        return 'No'

sox18['All Star'] = sox18.apply(star, axis = 1)
sox18[['Name','BA','OBP','All Star']]
# Out:
#                   Name     BA    OBP All Star
# 0           Sandy Leon  0.177  0.232       No
# 1       Mitch Moreland  0.245  0.325       No
# 2        Eduardo Nunez  0.265  0.289       No
# 3      Xander Bogaerts  0.288  0.360      Yes
# 4        Rafael Devers  0.240  0.298       No
# 5    Andrew Benintendi  0.290  0.366      Yes
# 6   Jackie Bradley Jr.  0.234  0.314       No
# 7         Mookie Betts  0.346  0.438      Yes
# 8        J.D. Martinez  0.330  0.402      Yes
# 9           Brock Holt  0.277  0.362      Yes
# 10   Christian Vazquez  0.207  0.257       No
# 11       Blake Swihart  0.229  0.285       No
# 12      Hanley Ramirez  0.254  0.313       No
# 13        Steve Pearce  0.279  0.394      Yes
# 14         Ian Kinsler  0.242  0.294       No
# 15         Tzu-Wei Lin  0.246  0.329       No
# 16          Sam Travis  0.222  0.263       No
# 17    Brandon Phillips  0.130  0.259       No
# 18      Dustin Pedroia  0.091  0.231       No
# 19          Dan Butler  0.167  0.143       No

# %% [markdown]
# ### #3 - Find the Mean for the Red Sox <br>
# <p>Compare both years of Red Sox Hitting Data and diaplay the following</p>
# <p>Get total number of home runs and rbi's</p>
# <p>Based on the total number of HR's who had the better year? What about by total RBI's?</p>

# %%
#Test to make sure you have the correct data
sox17 = pd.read_csv('../files/redsox_2017_hitting.txt')
print(f"Redsox 2017 HR total: {sox17['HR'].sum()}")
print(f"Redsox 2018 HR total: {sox18['HR'].sum()}")

if sox17['HR'].sum() > sox18['HR'].sum():
    print('The 2017 Redsox had a better HR counter\n')
else:
    print('The 2018 Redsox had a better HR counter\n')

print(f"Redsox 2017 RBI total: {sox17['RBI'].sum()}")
print(f"Redsox 2018 RBI total: {sox18['RBI'].sum()}")

if sox17['RBI'].sum() > sox18['HR'].sum():
    print('The 2017 Redsox had a better RBI counter')
else:
    print('The 2018 Redsox had a better RBI counter')
# Out:
# Redsox 2017 HR total: 168
# Redsox 2018 HR total: 208
# The 2018 Redsox had a better HR counter
#
# Redsox 2017 RBI total: 735
# Redsox 2018 RBI total: 826
# The 2017 Redsox had a better RBI counter
